# %%
import pickle
import matplotlib.pyplot as plt

# %%
results_naive = pickle.load(open("../results/US_N=10000_p=0.01_T=100/naive/results_0.pickle", "rb"))

# %%
results_naive
# Out:
# [{'cum_num_positives': 1,
#   'cum_num_identified': 0,
#   'cum_sensitivity': 0.0,
#   'cum_num_tests': 20,
#   'day': 0,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 2,
#   'cum_num_identified': 1,
#   'cum_sensitivity': 0.5,
#   'cum_num_tests': 45,
#   'day': 1,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 4,
#   'cum_num_identified': 3,
#   'cum_sensitivity': 0.75,
#   'cum_num_tests': 75,
#   'day': 2,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 4,
#   'cum_num_identified': 3,
#   'cum_sensitivity': 0.75,
#   'cum_num_tests': 95,
#   'day': 3,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 4,
#   'cum_num_identified': 3,
#   'cum_sensitivity': 0.75,
#   'cum_num_tests': 115,
#   'day': 4,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 6,
#   'cum_num_identified': 5,
#   'cum_sensitivity': 0.8333333333333334,
#   'cum_num_tests': 145,
#   'day': 5,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 6,
#   'cum_num_identified': 5,
#   'cum_sensitivity': 0.8333333333333334,
#   'cum_num_tests': 165,
#   'day': 6,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 6,
#   'cum_num_identified': 5,
#   'cum_sensitivity': 0.8333333333333334,
#   'cum_num_tests': 185,
#   'day': 7,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 10,
#   'cum_num_identified': 8,
#   'cum_sensitivity': 0.8,
#   'cum_num_tests': 220,
#   'day': 8,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])},
#  {'cum_num_positives': 11,
#   'cum_num_identified': 9,
#   'cum_sensitivity': 0.8181818181818182,
#   'cum_num_tests': 245,
#   'day': 9,
#   'cumRecovered': array([0., 0., 0., ..., 0., 0., 0.])}]

# %%
for metric in ['cum_sensitivity', 'cum_num_identified', 'cum_num_tests', ]:
    plt.plot([result[metric] for result in results_naive])
    # plt.plot([result[metric] for result in results_corr])
    plt.title(metric)
    plt.legend(['naive', 'correlated'])
    plt.show()
