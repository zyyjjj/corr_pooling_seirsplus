# %%
import pickle
import matplotlib.pyplot as plt

# %%
# results_naive = pickle.load(open("../results/US_N=10000_p=0.01_T=100/naive/results_0.pickle", "rb"))
# results_corr = pickle.load(open("../results/US_N=10000_p=0.01_T=100/naive/correlated/results_0.pickle", "rb"))

results_naive = pickle.load(open("../results/US_N=1000_p=0.5_T=100/naive/results_0.pickle", "rb"))
results_corr = pickle.load(open("../results/US_N=1000_p=0.5_T=100/correlated/results_0.pickle", "rb"))

# %%
results_naive[0].keys()
# Out:
# dict_keys(['cum_num_positives', 'cum_num_identified', 'cum_sensitivity', 'cum_num_tests', 'day', 'cumRecovered'])

# %%
for metric in ['cum_sensitivity', 'cum_num_identified', 'cum_num_tests', 'cumRecovered']:
    plt.plot([result[metric] for result in results_naive])
    # plt.plot([result[metric] for result in results_corr])
    plt.title(metric)
    plt.legend(['naive', 'correlated'])
    plt.show()
