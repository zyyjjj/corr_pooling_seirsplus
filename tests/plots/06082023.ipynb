# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import random
import numpy as np
from seirsplus.networks import generate_demographic_contact_network, household_country_data
from seirsplus.viral_model import ViralExtSEIRNetworkModel
from seirsplus.sim_loops_pooled_test import SimulationRunner

# %% [markdown]
# ## Note: these are results of sensitivity analyses started 6/7/2023 night, using parameter values in `test_reduced_0607.yaml`. Only pool size is varied.

# %%
import pickle

NUM_TRIALS = 20


param_config = {
    "pop_size_default": 10000,

    "init_prev_default": 0.01,

    'horizon_default': 100,

    'num_groups_default': 10,

    "pool_size": [40, 50, 60],
    "pool_size_default": 5,

    "beta_default": 0.5, # transmissibility
    "sigma_default": 0.2, # rate E --> I_pre
    "lamda_default": 0.5, # rate I_pre --> I_(a)sym
    "gamma_default": 0.25 # rate I_sym --> R
}

# %% [markdown]
# # Vary pool size

# %%
paths = {}

param_to_vary = "pool_size"


for param_val in param_config[param_to_vary]:
    # path = "../results/US"
    path = "/home/yz685/corr_pooling_seirsplus/results/US"

    for param_name in [
        "pop_size", "init_prev", "num_groups", "pool_size", "horizon", 
        "beta", "sigma", "lamda", "gamma"
    ]:
            
        if param_name == param_to_vary:
            path += f"_{param_name}={param_val}"
        else:
            path += f"_{param_name}={param_config[param_name+'_default']}"
        
    paths[param_val] = path

# %%
paths
# Out:
# {40: '/home/yz685/corr_pooling_seirsplus/results/US_pop_size=10000_init_prev=0.01_num_groups=10_pool_size=40_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25',
#  50: '/home/yz685/corr_pooling_seirsplus/results/US_pop_size=10000_init_prev=0.01_num_groups=10_pool_size=50_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25',
#  60: '/home/yz685/corr_pooling_seirsplus/results/US_pop_size=10000_init_prev=0.01_num_groups=10_pool_size=60_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25'}

# %%
from collections import defaultdict
def defaultdict_list():
    return defaultdict(list)

results = defaultdict(defaultdict_list) # dict of dict of list of individual results

for param_val, path in paths.items():
    for pooling_strategy in ["naive", "correlated"]:
        for i in range(NUM_TRIALS):
            filepath = path + f"/{pooling_strategy}/results_{i}.pickle"
            try:
                with open(filepath, "rb") as f:
                    results[pooling_strategy][param_val].append(pickle.load(f))
            except Exception as e:
                print("error: ", e)
                continue

# %%
results["correlated"]
# Out:
# defaultdict(list,
#             {40: [[{'cum_positives_screened': 9,
#                 'cum_positives_identified': 0,
#                 'cum_sensitivity': 0.0,
#                 'cum_num_tests': 25,
#                 'day': 0,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 100.0,
#                 'cumActiveInfections': 100.0,
#                 'mean_num_positives_in_positive_pool': 1.125,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 19,
#                 'cum_positives_identified': 0,
#                 'cum_sensitivity': 0.0,
#                 'cum_num_tests': 50,
#                 'day': 1,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 100.0,
#                 'cumActiveInfections': 100.0,
#                 'mean_num_positives_in_positive_pool': 1.4285714285714286,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 48,
#                 'cum_positives_identified': 15,
#                 'cum_sensitivity': 0.3125,
#                 'cum_num_tests': 395,
#                 'day': 2,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 219.0,
#                 'cumActiveInfections': 219.0,
#                 'mean_num_positives_in_positive_pool': 3.625,
#                 'daily_sensitivity': 0.5172413793103449},
#                {'cum_positives_screened': 87,
#                 'cum_positives_identified': 38,
#                 'cum_sensitivity': 0.4367816091954023,
#                 'cum_num_tests': 860,
#                 'day': 3,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 326.0,
#                 'cumActiveInfections': 311.0,
#                 'mean_num_positives_in_positive_pool': 3.5454545454545454,
#                 'daily_sensitivity': 0.5897435897435898},
#                {'cum_positives_screened': 125,
#                 'cum_positives_identified': 76,
#                 'cum_sensitivity': 0.608,
#                 'cum_num_tests': 1245,
#                 'day': 4,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 334.0,
#                 'cumActiveInfections': 296.0,
#                 'mean_num_positives_in_positive_pool': 4.222222222222222,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 171,
#                 'cum_positives_identified': 121,
#                 'cum_sensitivity': 0.7076023391812866,
#                 'cum_num_tests': 1710,
#                 'day': 5,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 347.0,
#                 'cumActiveInfections': 271.0,
#                 'mean_num_positives_in_positive_pool': 4.181818181818182,
#                 'daily_sensitivity': 0.9782608695652174},
#                {'cum_positives_screened': 210,
#                 'cum_positives_identified': 159,
#                 'cum_sensitivity': 0.7571428571428571,
#                 'cum_num_tests': 2095,
#                 'day': 6,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 364.0,
#                 'cumActiveInfections': 243.0,
#                 'mean_num_positives_in_positive_pool': 4.333333333333333,
#                 'daily_sensitivity': 0.9743589743589743},
#                {'cum_positives_screened': 235,
#                 'cum_positives_identified': 184,
#                 'cum_sensitivity': 0.7829787234042553,
#                 'cum_num_tests': 2360,
#                 'day': 7,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 387.0,
#                 'cumActiveInfections': 228.0,
#                 'mean_num_positives_in_positive_pool': 4.166666666666667,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 271,
#                 'cum_positives_identified': 219,
#                 'cum_sensitivity': 0.8081180811808119,
#                 'cum_num_tests': 2705,
#                 'day': 8,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 402.0,
#                 'cumActiveInfections': 218.0,
#                 'mean_num_positives_in_positive_pool': 4.0,
#                 'daily_sensitivity': 0.9722222222222222},
#                {'cum_positives_screened': 311,
#                 'cum_positives_identified': 259,
#                 'cum_sensitivity': 0.8327974276527331,
#                 'cum_num_tests': 3050,
#                 'day': 9,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 416.0,
#                 'cumActiveInfections': 197.0,
#                 'mean_num_positives_in_positive_pool': 5.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 337,
#                 'cum_positives_identified': 283,
#                 'cum_sensitivity': 0.8397626112759644,
#                 'cum_num_tests': 3355,
#                 'day': 10,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 428.0,
#                 'cumActiveInfections': 169.0,
#                 'mean_num_positives_in_positive_pool': 3.25,
#                 'daily_sensitivity': 0.9230769230769231},
#                {'cum_positives_screened': 452,
#                 'cum_positives_identified': 382,
#                 'cum_sensitivity': 0.8451327433628318,
#                 'cum_num_tests': 4300,
#                 'day': 11,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 445.0,
#                 'cumActiveInfections': 162.0,
#                 'mean_num_positives_in_positive_pool': 4.791666666666667,
#                 'daily_sensitivity': 0.8608695652173913},
#                {'cum_positives_screened': 472,
#                 'cum_positives_identified': 398,
#                 'cum_sensitivity': 0.8432203389830508,
#                 'cum_num_tests': 4565,
#                 'day': 12,
#                 'cumRecovered': 33.0,
#                 'cumInfections': 462.0,
#                 'cumActiveInfections': 78.0,
#                 'mean_num_positives_in_positive_pool': 2.5,
#                 'daily_sensitivity': 0.8},
#                {'cum_positives_screened': 487,
#                 'cum_positives_identified': 409,
#                 'cum_sensitivity': 0.839835728952772,
#                 'cum_num_tests': 4790,
#                 'day': 13,
#                 'cumRecovered': 69.0,
#                 'cumInfections': 479.0,
#                 'cumActiveInfections': 74.0,
#                 'mean_num_positives_in_positive_pool': 3.0,
#                 'daily_sensitivity': 0.7333333333333333},
#                {'cum_positives_screened': 490,
#                 'cum_positives_identified': 412,
#                 'cum_sensitivity': 0.8408163265306122,
#                 'cum_num_tests': 4895,
#                 'day': 14,
#                 'cumRecovered': 98.0,
#                 'cumInfections': 493.0,
#                 'cumActiveInfections': 73.0,
#                 'mean_num_positives_in_positive_pool': 1.5,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 493,
#                 'cum_positives_identified': 415,
#                 'cum_sensitivity': 0.8417849898580122,
#                 'cum_num_tests': 5039,
#                 'day': 15,
#                 'cumRecovered': 101.0,
#                 'cumInfections': 502.0,
#                 'cumActiveInfections': 78.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 496,
#                 'cum_positives_identified': 417,
#                 'cum_sensitivity': 0.8407258064516129,
#                 'cum_num_tests': 5132,
#                 'day': 16,
#                 'cumRecovered': 134.0,
#                 'cumInfections': 515.0,
#                 'cumActiveInfections': 88.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.6666666666666666},
#                {'cum_positives_screened': 496,
#                 'cum_positives_identified': 417,
#                 'cum_sensitivity': 0.8407258064516129,
#                 'cum_num_tests': 5157,
#                 'day': 17,
#                 'cumRecovered': 199.0,
#                 'cumInfections': 538.0,
#                 'cumActiveInfections': 110.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 497,
#                 'cum_positives_identified': 418,
#                 'cum_sensitivity': 0.8410462776659959,
#                 'cum_num_tests': 5220,
#                 'day': 18,
#                 'cumRecovered': 271.0,
#                 'cumInfections': 550.0,
#                 'cumActiveInfections': 122.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 497,
#                 'cum_positives_identified': 418,
#                 'cum_sensitivity': 0.8410462776659959,
#                 'cum_num_tests': 5244,
#                 'day': 19,
#                 'cumRecovered': 335.0,
#                 'cumInfections': 556.0,
#                 'cumActiveInfections': 125.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 500,
#                 'cum_positives_identified': 421,
#                 'cum_sensitivity': 0.842,
#                 'cum_num_tests': 5347,
#                 'day': 20,
#                 'cumRecovered': 355.0,
#                 'cumInfections': 568.0,
#                 'cumActiveInfections': 137.0,
#                 'mean_num_positives_in_positive_pool': 1.5,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 635,
#                 'cum_positives_identified': 547,
#                 'cum_sensitivity': 0.8614173228346457,
#                 'cum_num_tests': 6271,
#                 'day': 21,
#                 'cumRecovered': 372.0,
#                 'cumInfections': 577.0,
#                 'cumActiveInfections': 141.0,
#                 'mean_num_positives_in_positive_pool': 5.869565217391305,
#                 'daily_sensitivity': 0.9333333333333333},
#                {'cum_positives_screened': 636,
#                 'cum_positives_identified': 547,
#                 'cum_sensitivity': 0.860062893081761,
#                 'cum_num_tests': 6296,
#                 'day': 22,
#                 'cumRecovered': 386.0,
#                 'cumInfections': 588.0,
#                 'cumActiveInfections': 25.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 636,
#                 'cum_positives_identified': 547,
#                 'cum_sensitivity': 0.860062893081761,
#                 'cum_num_tests': 6321,
#                 'day': 23,
#                 'cumRecovered': 407.0,
#                 'cumInfections': 596.0,
#                 'cumActiveInfections': 34.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 636,
#                 'cum_positives_identified': 547,
#                 'cum_sensitivity': 0.860062893081761,
#                 'cum_num_tests': 6346,
#                 'day': 24,
#                 'cumRecovered': 425.0,
#                 'cumInfections': 604.0,
#                 'cumActiveInfections': 41.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 639,
#                 'cum_positives_identified': 550,
#                 'cum_sensitivity': 0.8607198748043818,
#                 'cum_num_tests': 6491,
#                 'day': 25,
#                 'cumRecovered': 438.0,
#                 'cumInfections': 614.0,
#                 'cumActiveInfections': 51.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 641,
#                 'cum_positives_identified': 552,
#                 'cum_sensitivity': 0.8611544461778471,
#                 'cum_num_tests': 6556,
#                 'day': 26,
#                 'cumRecovered': 450.0,
#                 'cumInfections': 622.0,
#                 'cumActiveInfections': 60.0,
#                 'mean_num_positives_in_positive_pool': 2.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 641,
#                 'cum_positives_identified': 552,
#                 'cum_sensitivity': 0.8611544461778471,
#                 'cum_num_tests': 6581,
#                 'day': 27,
#                 'cumRecovered': 464.0,
#                 'cumInfections': 627.0,
#                 'cumActiveInfections': 59.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 641,
#                 'cum_positives_identified': 552,
#                 'cum_sensitivity': 0.8611544461778471,
#                 'cum_num_tests': 6606,
#                 'day': 28,
#                 'cumRecovered': 480.0,
#                 'cumInfections': 636.0,
#                 'cumActiveInfections': 68.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 642,
#                 'cum_positives_identified': 553,
#                 'cum_sensitivity': 0.8613707165109035,
#                 'cum_num_tests': 6671,
#                 'day': 29,
#                 'cumRecovered': 501.0,
#                 'cumInfections': 643.0,
#                 'cumActiveInfections': 75.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 642,
#                 'cum_positives_identified': 553,
#                 'cum_sensitivity': 0.8613707165109035,
#                 'cum_num_tests': 6696,
#                 'day': 30,
#                 'cumRecovered': 511.0,
#                 'cumInfections': 649.0,
#                 'cumActiveInfections': 80.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 724,
#                 'cum_positives_identified': 627,
#                 'cum_sensitivity': 0.8660220994475138,
#                 'cum_num_tests': 7552,
#                 'day': 31,
#                 'cumRecovered': 527.0,
#                 'cumInfections': 655.0,
#                 'cumActiveInfections': 84.0,
#                 'mean_num_positives_in_positive_pool': 3.727272727272727,
#                 'daily_sensitivity': 0.9024390243902439},
#                {'cum_positives_screened': 725,
#                 'cum_positives_identified': 628,
#                 'cum_sensitivity': 0.8662068965517241,
#                 'cum_num_tests': 7617,
#                 'day': 32,
#                 'cumRecovered': 539.0,
#                 'cumInfections': 659.0,
#                 'cumActiveInfections': 13.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 725,
#                 'cum_positives_identified': 628,
#                 'cum_sensitivity': 0.8662068965517241,
#                 'cum_num_tests': 7642,
#                 'day': 33,
#                 'cumRecovered': 559.0,
#                 'cumInfections': 666.0,
#                 'cumActiveInfections': 19.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 725,
#                 'cum_positives_identified': 628,
#                 'cum_sensitivity': 0.8662068965517241,
#                 'cum_num_tests': 7667,
#                 'day': 34,
#                 'cumRecovered': 570.0,
#                 'cumInfections': 671.0,
#                 'cumActiveInfections': 24.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 726,
#                 'cum_positives_identified': 629,
#                 'cum_sensitivity': 0.8663911845730028,
#                 'cum_num_tests': 7732,
#                 'day': 35,
#                 'cumRecovered': 578.0,
#                 'cumInfections': 675.0,
#                 'cumActiveInfections': 27.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 726,
#                 'cum_positives_identified': 629,
#                 'cum_sensitivity': 0.8663911845730028,
#                 'cum_num_tests': 7757,
#                 'day': 36,
#                 'cumRecovered': 585.0,
#                 'cumInfections': 679.0,
#                 'cumActiveInfections': 31.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 726,
#                 'cum_positives_identified': 629,
#                 'cum_sensitivity': 0.8663911845730028,
#                 'cum_num_tests': 7782,
#                 'day': 37,
#                 'cumRecovered': 598.0,
#                 'cumInfections': 680.0,
#                 'cumActiveInfections': 31.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 726,
#                 'cum_positives_identified': 629,
#                 'cum_sensitivity': 0.8663911845730028,
#                 'cum_num_tests': 7807,
#                 'day': 38,
#                 'cumRecovered': 601.0,
#                 'cumInfections': 682.0,
#                 'cumActiveInfections': 33.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 727,
#                 'cum_positives_identified': 630,
#                 'cum_sensitivity': 0.8665749656121046,
#                 'cum_num_tests': 7872,
#                 'day': 39,
#                 'cumRecovered': 610.0,
#                 'cumInfections': 683.0,
#                 'cumActiveInfections': 34.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 727,
#                 'cum_positives_identified': 630,
#                 'cum_sensitivity': 0.8665749656121046,
#                 'cum_num_tests': 7897,
#                 'day': 40,
#                 'cumRecovered': 615.0,
#                 'cumInfections': 686.0,
#                 'cumActiveInfections': 36.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 761,
#                 'cum_positives_identified': 658,
#                 'cum_sensitivity': 0.8646517739816032,
#                 'cum_num_tests': 8407,
#                 'day': 41,
#                 'cumRecovered': 622.0,
#                 'cumInfections': 686.0,
#                 'cumActiveInfections': 35.0,
#                 'mean_num_positives_in_positive_pool': 2.125,
#                 'daily_sensitivity': 0.8235294117647058},
#                {'cum_positives_screened': 761,
#                 'cum_positives_identified': 658,
#                 'cum_sensitivity': 0.8646517739816032,
#                 'cum_num_tests': 8432,
#                 'day': 42,
#                 'cumRecovered': 633.0,
#                 'cumInfections': 687.0,
#                 'cumActiveInfections': 4.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 761,
#                 'cum_positives_identified': 658,
#                 'cum_sensitivity': 0.8646517739816032,
#                 'cum_num_tests': 8457,
#                 'day': 43,
#                 'cumRecovered': 638.0,
#                 'cumInfections': 688.0,
#                 'cumActiveInfections': 5.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 761,
#                 'cum_positives_identified': 658,
#                 'cum_sensitivity': 0.8646517739816032,
#                 'cum_num_tests': 8482,
#                 'day': 44,
#                 'cumRecovered': 647.0,
#                 'cumInfections': 689.0,
#                 'cumActiveInfections': 6.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 762,
#                 'cum_positives_identified': 659,
#                 'cum_sensitivity': 0.8648293963254593,
#                 'cum_num_tests': 8547,
#                 'day': 45,
#                 'cumRecovered': 653.0,
#                 'cumInfections': 690.0,
#                 'cumActiveInfections': 6.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 762,
#                 'cum_positives_identified': 659,
#                 'cum_sensitivity': 0.8648293963254593,
#                 'cum_num_tests': 8572,
#                 'day': 46,
#                 'cumRecovered': 657.0,
#                 'cumInfections': 692.0,
#                 'cumActiveInfections': 8.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 762,
#                 'cum_positives_identified': 659,
#                 'cum_sensitivity': 0.8648293963254593,
#                 'cum_num_tests': 8597,
#                 'day': 47,
#                 'cumRecovered': 661.0,
#                 'cumInfections': 692.0,
#                 'cumActiveInfections': 7.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 762,
#                 'cum_positives_identified': 659,
#                 'cum_sensitivity': 0.8648293963254593,
#                 'cum_num_tests': 8622,
#                 'day': 48,
#                 'cumRecovered': 664.0,
#                 'cumInfections': 693.0,
#                 'cumActiveInfections': 8.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 762,
#                 'cum_positives_identified': 659,
#                 'cum_sensitivity': 0.8648293963254593,
#                 'cum_num_tests': 8647,
#                 'day': 49,
#                 'cumRecovered': 666.0,
#                 'cumInfections': 694.0,
#                 'cumActiveInfections': 9.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 762,
#                 'cum_positives_identified': 659,
#                 'cum_sensitivity': 0.8648293963254593,
#                 'cum_num_tests': 8672,
#                 'day': 50,
#                 'cumRecovered': 670.0,
#                 'cumInfections': 694.0,
#                 'cumActiveInfections': 9.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 8975,
#                 'day': 51,
#                 'cumRecovered': 680.0,
#                 'cumInfections': 694.0,
#                 'cumActiveInfections': 8.0,
#                 'mean_num_positives_in_positive_pool': 1.1428571428571428,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9000,
#                 'day': 52,
#                 'cumRecovered': 682.0,
#                 'cumInfections': 694.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9025,
#                 'day': 53,
#                 'cumRecovered': 685.0,
#                 'cumInfections': 694.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9050,
#                 'day': 54,
#                 'cumRecovered': 686.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9075,
#                 'day': 55,
#                 'cumRecovered': 686.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9100,
#                 'day': 56,
#                 'cumRecovered': 686.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9125,
#                 'day': 57,
#                 'cumRecovered': 686.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9150,
#                 'day': 58,
#                 'cumRecovered': 686.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9175,
#                 'day': 59,
#                 'cumRecovered': 688.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 770,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8662337662337662,
#                 'cum_num_tests': 9200,
#                 'day': 60,
#                 'cumRecovered': 690.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 771,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8651102464332037,
#                 'cum_num_tests': 9225,
#                 'day': 61,
#                 'cumRecovered': 691.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 771,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8651102464332037,
#                 'cum_num_tests': 9250,
#                 'day': 62,
#                 'cumRecovered': 693.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 771,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8651102464332037,
#                 'cum_num_tests': 9275,
#                 'day': 63,
#                 'cumRecovered': 693.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 771,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8651102464332037,
#                 'cum_num_tests': 9300,
#                 'day': 64,
#                 'cumRecovered': 693.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 771,
#                 'cum_positives_identified': 667,
#                 'cum_sensitivity': 0.8651102464332037,
#                 'cum_num_tests': 9325,
#                 'day': 65,
#                 'cumRecovered': 695.0,
#                 'cumInfections': 695.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan}],
#               [{'cum_positives_screened': 12,
#                 'cum_positives_identified': 0,
#                 'cum_sensitivity': 0.0,
#                 'cum_num_tests': 25,
#                 'day': 0,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 100.0,
#                 'cumActiveInfections': 100.0,
#                 'mean_num_positives_in_positive_pool': 1.2,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 21,
#                 'cum_positives_identified': 0,
#                 'cum_sensitivity': 0.0,
#                 'cum_num_tests': 50,
#                 'day': 1,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 100.0,
#                 'cumActiveInfections': 100.0,
#                 'mean_num_positives_in_positive_pool': 1.2857142857142858,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 47,
#                 'cum_positives_identified': 13,
#                 'cum_sensitivity': 0.2765957446808511,
#                 'cum_num_tests': 475,
#                 'day': 2,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 209.0,
#                 'cumActiveInfections': 209.0,
#                 'mean_num_positives_in_positive_pool': 2.3636363636363638,
#                 'daily_sensitivity': 0.5},
#                {'cum_positives_screened': 57,
#                 'cum_positives_identified': 21,
#                 'cum_sensitivity': 0.3684210526315789,
#                 'cum_num_tests': 820,
#                 'day': 3,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 323.0,
#                 'cumActiveInfections': 310.0,
#                 'mean_num_positives_in_positive_pool': 1.1111111111111112,
#                 'daily_sensitivity': 0.8},
#                {'cum_positives_screened': 90,
#                 'cum_positives_identified': 52,
#                 'cum_sensitivity': 0.5777777777777777,
#                 'cum_num_tests': 1245,
#                 'day': 4,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 329.0,
#                 'cumActiveInfections': 308.0,
#                 'mean_num_positives_in_positive_pool': 3.3,
#                 'daily_sensitivity': 0.9393939393939394},
#                {'cum_positives_screened': 113,
#                 'cum_positives_identified': 75,
#                 'cum_sensitivity': 0.6637168141592921,
#                 'cum_num_tests': 1550,
#                 'day': 5,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 346.0,
#                 'cumActiveInfections': 294.0,
#                 'mean_num_positives_in_positive_pool': 3.2857142857142856,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 131,
#                 'cum_positives_identified': 92,
#                 'cum_sensitivity': 0.7022900763358778,
#                 'cum_num_tests': 1775,
#                 'day': 6,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 365.0,
#                 'cumActiveInfections': 290.0,
#                 'mean_num_positives_in_positive_pool': 3.6,
#                 'daily_sensitivity': 0.9444444444444444},
#                {'cum_positives_screened': 166,
#                 'cum_positives_identified': 127,
#                 'cum_sensitivity': 0.7650602409638554,
#                 'cum_num_tests': 2120,
#                 'day': 7,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 382.0,
#                 'cumActiveInfections': 290.0,
#                 'mean_num_positives_in_positive_pool': 4.375,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 213,
#                 'cum_positives_identified': 174,
#                 'cum_sensitivity': 0.8169014084507042,
#                 'cum_num_tests': 2625,
#                 'day': 8,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 394.0,
#                 'cumActiveInfections': 267.0,
#                 'mean_num_positives_in_positive_pool': 3.9166666666666665,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 265,
#                 'cum_positives_identified': 226,
#                 'cum_sensitivity': 0.8528301886792453,
#                 'cum_num_tests': 3090,
#                 'day': 9,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 402.0,
#                 'cumActiveInfections': 228.0,
#                 'mean_num_positives_in_positive_pool': 4.7272727272727275,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 310,
#                 'cum_positives_identified': 267,
#                 'cum_sensitivity': 0.8612903225806452,
#                 'cum_num_tests': 3435,
#                 'day': 10,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 416.0,
#                 'cumActiveInfections': 190.0,
#                 'mean_num_positives_in_positive_pool': 5.0,
#                 'daily_sensitivity': 0.9111111111111111},
#                {'cum_positives_screened': 337,
#                 'cum_positives_identified': 288,
#                 'cum_sensitivity': 0.8545994065281899,
#                 'cum_num_tests': 3780,
#                 'day': 11,
#                 'cumRecovered': 0.0,
#                 'cumInfections': 437.0,
#                 'cumActiveInfections': 170.0,
#                 'mean_num_positives_in_positive_pool': 3.0,
#                 'daily_sensitivity': 0.7777777777777778},
#                {'cum_positives_screened': 362,
#                 'cum_positives_identified': 309,
#                 'cum_sensitivity': 0.8535911602209945,
#                 'cum_num_tests': 4122,
#                 'day': 12,
#                 'cumRecovered': 34.0,
#                 'cumInfections': 447.0,
#                 'cumActiveInfections': 153.0,
#                 'mean_num_positives_in_positive_pool': 2.7777777777777777,
#                 'daily_sensitivity': 0.84},
#                {'cum_positives_screened': 486,
#                 'cum_positives_identified': 420,
#                 'cum_sensitivity': 0.8641975308641975,
#                 'cum_num_tests': 5019,
#                 'day': 13,
#                 'cumRecovered': 66.0,
#                 'cumInfections': 458.0,
#                 'cumActiveInfections': 138.0,
#                 'mean_num_positives_in_positive_pool': 4.96,
#                 'daily_sensitivity': 0.8951612903225806},
#                {'cum_positives_screened': 487,
#                 'cum_positives_identified': 420,
#                 'cum_sensitivity': 0.8624229979466119,
#                 'cum_num_tests': 5044,
#                 'day': 14,
#                 'cumRecovered': 98.0,
#                 'cumInfections': 468.0,
#                 'cumActiveInfections': 35.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 488,
#                 'cum_positives_identified': 421,
#                 'cum_sensitivity': 0.8627049180327869,
#                 'cum_num_tests': 5109,
#                 'day': 15,
#                 'cumRecovered': 98.0,
#                 'cumInfections': 474.0,
#                 'cumActiveInfections': 41.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 490,
#                 'cum_positives_identified': 423,
#                 'cum_sensitivity': 0.863265306122449,
#                 'cum_num_tests': 5214,
#                 'day': 16,
#                 'cumRecovered': 136.0,
#                 'cumInfections': 487.0,
#                 'cumActiveInfections': 52.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 492,
#                 'cum_positives_identified': 424,
#                 'cum_sensitivity': 0.8617886178861789,
#                 'cum_num_tests': 5279,
#                 'day': 17,
#                 'cumRecovered': 194.0,
#                 'cumInfections': 501.0,
#                 'cumActiveInfections': 65.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.5},
#                {'cum_positives_screened': 494,
#                 'cum_positives_identified': 426,
#                 'cum_sensitivity': 0.8623481781376519,
#                 'cum_num_tests': 5343,
#                 'day': 18,
#                 'cumRecovered': 263.0,
#                 'cumInfections': 507.0,
#                 'cumActiveInfections': 67.0,
#                 'mean_num_positives_in_positive_pool': 2.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 494,
#                 'cum_positives_identified': 426,
#                 'cum_sensitivity': 0.8623481781376519,
#                 'cum_num_tests': 5367,
#                 'day': 19,
#                 'cumRecovered': 326.0,
#                 'cumInfections': 511.0,
#                 'cumActiveInfections': 68.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 495,
#                 'cum_positives_identified': 426,
#                 'cum_sensitivity': 0.8606060606060606,
#                 'cum_num_tests': 5391,
#                 'day': 20,
#                 'cumRecovered': 357.0,
#                 'cumInfections': 518.0,
#                 'cumActiveInfections': 73.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 496,
#                 'cum_positives_identified': 427,
#                 'cum_sensitivity': 0.8608870967741935,
#                 'cum_num_tests': 5456,
#                 'day': 21,
#                 'cumRecovered': 371.0,
#                 'cumInfections': 522.0,
#                 'cumActiveInfections': 77.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 498,
#                 'cum_positives_identified': 429,
#                 'cum_sensitivity': 0.8614457831325302,
#                 'cum_num_tests': 5561,
#                 'day': 22,
#                 'cumRecovered': 389.0,
#                 'cumInfections': 533.0,
#                 'cumActiveInfections': 87.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 591,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8663282571912013,
#                 'cum_num_tests': 6424,
#                 'day': 23,
#                 'cumRecovered': 405.0,
#                 'cumInfections': 543.0,
#                 'cumActiveInfections': 93.0,
#                 'mean_num_positives_in_positive_pool': 4.428571428571429,
#                 'daily_sensitivity': 0.8924731182795699},
#                {'cum_positives_screened': 591,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8663282571912013,
#                 'cum_num_tests': 6449,
#                 'day': 24,
#                 'cumRecovered': 415.0,
#                 'cumInfections': 548.0,
#                 'cumActiveInfections': 12.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 591,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8663282571912013,
#                 'cum_num_tests': 6474,
#                 'day': 25,
#                 'cumRecovered': 424.0,
#                 'cumInfections': 554.0,
#                 'cumActiveInfections': 18.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 591,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8663282571912013,
#                 'cum_num_tests': 6499,
#                 'day': 26,
#                 'cumRecovered': 433.0,
#                 'cumInfections': 559.0,
#                 'cumActiveInfections': 23.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 592,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8648648648648649,
#                 'cum_num_tests': 6524,
#                 'day': 27,
#                 'cumRecovered': 452.0,
#                 'cumInfections': 566.0,
#                 'cumActiveInfections': 30.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.0},
#                {'cum_positives_screened': 592,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8648648648648649,
#                 'cum_num_tests': 6549,
#                 'day': 28,
#                 'cumRecovered': 463.0,
#                 'cumInfections': 571.0,
#                 'cumActiveInfections': 39.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 592,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8648648648648649,
#                 'cum_num_tests': 6574,
#                 'day': 29,
#                 'cumRecovered': 472.0,
#                 'cumInfections': 579.0,
#                 'cumActiveInfections': 43.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 592,
#                 'cum_positives_identified': 512,
#                 'cum_sensitivity': 0.8648648648648649,
#                 'cum_num_tests': 6599,
#                 'day': 30,
#                 'cumRecovered': 479.0,
#                 'cumInfections': 584.0,
#                 'cumActiveInfections': 48.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 594,
#                 'cum_positives_identified': 514,
#                 'cum_sensitivity': 0.8653198653198653,
#                 'cum_num_tests': 6664,
#                 'day': 31,
#                 'cumRecovered': 489.0,
#                 'cumInfections': 587.0,
#                 'cumActiveInfections': 51.0,
#                 'mean_num_positives_in_positive_pool': 2.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 594,
#                 'cum_positives_identified': 514,
#                 'cum_sensitivity': 0.8653198653198653,
#                 'cum_num_tests': 6689,
#                 'day': 32,
#                 'cumRecovered': 498.0,
#                 'cumInfections': 593.0,
#                 'cumActiveInfections': 55.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 651,
#                 'cum_positives_identified': 565,
#                 'cum_sensitivity': 0.8678955453149002,
#                 'cum_num_tests': 7389,
#                 'day': 33,
#                 'cumRecovered': 512.0,
#                 'cumInfections': 597.0,
#                 'cumActiveInfections': 59.0,
#                 'mean_num_positives_in_positive_pool': 3.0,
#                 'daily_sensitivity': 0.8947368421052632},
#                {'cum_positives_screened': 651,
#                 'cum_positives_identified': 565,
#                 'cum_sensitivity': 0.8678955453149002,
#                 'cum_num_tests': 7414,
#                 'day': 34,
#                 'cumRecovered': 514.0,
#                 'cumInfections': 600.0,
#                 'cumActiveInfections': 11.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 651,
#                 'cum_positives_identified': 565,
#                 'cum_sensitivity': 0.8678955453149002,
#                 'cum_num_tests': 7439,
#                 'day': 35,
#                 'cumRecovered': 523.0,
#                 'cumInfections': 601.0,
#                 'cumActiveInfections': 12.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 651,
#                 'cum_positives_identified': 565,
#                 'cum_sensitivity': 0.8678955453149002,
#                 'cum_num_tests': 7464,
#                 'day': 36,
#                 'cumRecovered': 529.0,
#                 'cumInfections': 603.0,
#                 'cumActiveInfections': 14.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 652,
#                 'cum_positives_identified': 566,
#                 'cum_sensitivity': 0.8680981595092024,
#                 'cum_num_tests': 7529,
#                 'day': 37,
#                 'cumRecovered': 532.0,
#                 'cumInfections': 607.0,
#                 'cumActiveInfections': 18.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 652,
#                 'cum_positives_identified': 566,
#                 'cum_sensitivity': 0.8680981595092024,
#                 'cum_num_tests': 7554,
#                 'day': 38,
#                 'cumRecovered': 540.0,
#                 'cumInfections': 611.0,
#                 'cumActiveInfections': 26.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 652,
#                 'cum_positives_identified': 566,
#                 'cum_sensitivity': 0.8680981595092024,
#                 'cum_num_tests': 7579,
#                 'day': 39,
#                 'cumRecovered': 550.0,
#                 'cumInfections': 612.0,
#                 'cumActiveInfections': 21.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 652,
#                 'cum_positives_identified': 566,
#                 'cum_sensitivity': 0.8680981595092024,
#                 'cum_num_tests': 7604,
#                 'day': 40,
#                 'cumRecovered': 557.0,
#                 'cumInfections': 612.0,
#                 'cumActiveInfections': 21.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 653,
#                 'cum_positives_identified': 567,
# ...
#                 'cum_positives_identified': 710,
#                 'cum_sensitivity': 0.8830845771144279,
#                 'cum_num_tests': 11369,
#                 'day': 64,
#                 'cumRecovered': 728.0,
#                 'cumInfections': 737.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 804,
#                 'cum_positives_identified': 710,
#                 'cum_sensitivity': 0.8830845771144279,
#                 'cum_num_tests': 11386,
#                 'day': 65,
#                 'cumRecovered': 729.0,
#                 'cumInfections': 737.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 804,
#                 'cum_positives_identified': 710,
#                 'cum_sensitivity': 0.8830845771144279,
#                 'cum_num_tests': 11403,
#                 'day': 66,
#                 'cumRecovered': 730.0,
#                 'cumInfections': 737.0,
#                 'cumActiveInfections': 1.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 804,
#                 'cum_positives_identified': 710,
#                 'cum_sensitivity': 0.8830845771144279,
#                 'cum_num_tests': 11420,
#                 'day': 67,
#                 'cumRecovered': 731.0,
#                 'cumInfections': 738.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 804,
#                 'cum_positives_identified': 710,
#                 'cum_sensitivity': 0.8830845771144279,
#                 'cum_num_tests': 11437,
#                 'day': 68,
#                 'cumRecovered': 731.0,
#                 'cumInfections': 739.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 804,
#                 'cum_positives_identified': 710,
#                 'cum_sensitivity': 0.8830845771144279,
#                 'cum_num_tests': 11454,
#                 'day': 69,
#                 'cumRecovered': 731.0,
#                 'cumInfections': 739.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 804,
#                 'cum_positives_identified': 710,
#                 'cum_sensitivity': 0.8830845771144279,
#                 'cum_num_tests': 11471,
#                 'day': 70,
#                 'cumRecovered': 732.0,
#                 'cumInfections': 739.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11668,
#                 'day': 71,
#                 'cumRecovered': 733.0,
#                 'cumInfections': 740.0,
#                 'cumActiveInfections': 4.0,
#                 'mean_num_positives_in_positive_pool': 1.3333333333333333,
#                 'daily_sensitivity': 0.75},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11685,
#                 'day': 72,
#                 'cumRecovered': 735.0,
#                 'cumInfections': 741.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11702,
#                 'day': 73,
#                 'cumRecovered': 736.0,
#                 'cumInfections': 741.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11719,
#                 'day': 74,
#                 'cumRecovered': 736.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11736,
#                 'day': 75,
#                 'cumRecovered': 736.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11753,
#                 'day': 76,
#                 'cumRecovered': 736.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11770,
#                 'day': 77,
#                 'cumRecovered': 736.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11787,
#                 'day': 78,
#                 'cumRecovered': 736.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11804,
#                 'day': 79,
#                 'cumRecovered': 737.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 808,
#                 'cum_positives_identified': 713,
#                 'cum_sensitivity': 0.8824257425742574,
#                 'cum_num_tests': 11821,
#                 'day': 80,
#                 'cumRecovered': 738.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 810,
#                 'cum_positives_identified': 715,
#                 'cum_sensitivity': 0.8827160493827161,
#                 'cum_num_tests': 11958,
#                 'day': 81,
#                 'cumRecovered': 738.0,
#                 'cumInfections': 742.0,
#                 'cumActiveInfections': 3.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 810,
#                 'cum_positives_identified': 715,
#                 'cum_sensitivity': 0.8827160493827161,
#                 'cum_num_tests': 11975,
#                 'day': 82,
#                 'cumRecovered': 738.0,
#                 'cumInfections': 743.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12052,
#                 'day': 83,
#                 'cumRecovered': 739.0,
#                 'cumInfections': 743.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 1.0},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12069,
#                 'day': 84,
#                 'cumRecovered': 739.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12086,
#                 'day': 85,
#                 'cumRecovered': 739.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12103,
#                 'day': 86,
#                 'cumRecovered': 739.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12120,
#                 'day': 87,
#                 'cumRecovered': 740.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12137,
#                 'day': 88,
#                 'cumRecovered': 740.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12154,
#                 'day': 89,
#                 'cumRecovered': 741.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 811,
#                 'cum_positives_identified': 716,
#                 'cum_sensitivity': 0.8828606658446363,
#                 'cum_num_tests': 12171,
#                 'day': 90,
#                 'cumRecovered': 742.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12248,
#                 'day': 91,
#                 'cumRecovered': 742.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': 1.0,
#                 'daily_sensitivity': 0.5},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12265,
#                 'day': 92,
#                 'cumRecovered': 742.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12282,
#                 'day': 93,
#                 'cumRecovered': 742.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 2.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12299,
#                 'day': 94,
#                 'cumRecovered': 743.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12316,
#                 'day': 95,
#                 'cumRecovered': 744.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12333,
#                 'day': 96,
#                 'cumRecovered': 744.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12350,
#                 'day': 97,
#                 'cumRecovered': 744.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12367,
#                 'day': 98,
#                 'cumRecovered': 744.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan},
#                {'cum_positives_screened': 813,
#                 'cum_positives_identified': 717,
#                 'cum_sensitivity': 0.8819188191881919,
#                 'cum_num_tests': 12384,
#                 'day': 99,
#                 'cumRecovered': 744.0,
#                 'cumInfections': 744.0,
#                 'cumActiveInfections': 0.0,
#                 'mean_num_positives_in_positive_pool': nan,
#                 'daily_sensitivity': nan}]]})

# %%
PARAM_VAL= 60
metrics = set(results["correlated"][PARAM_VAL][0][0].keys()) - set(["day"])

for metric in metrics:

    naive_results = []
    correlated_results = []

    for SEED in range(20):

        naive_results.append(
            [x[metric]\
            for x in results["naive"][PARAM_VAL][SEED]]
        )
        correlated_results.append(
            [x[metric]\
            for x in results["correlated"][PARAM_VAL][SEED]]
        )

    naive_results_ = np.array([(xi+[None]*(100-len(xi)))[:100] for xi in naive_results], dtype=float)
    correlated_results_ = np.array([(xi+[None]*(100-len(xi)))[:100] for xi in correlated_results][:100], dtype=float)

    naive_mean = np.nanmean(naive_results_, axis=0)
    naive_std = np.nanstd(naive_results_, axis=0)
    correlated_mean = np.nanmean(correlated_results_, axis=0)
    correlated_std = np.nanstd(correlated_results_, axis=0)

    plt.plot(naive_mean, color="mediumpurple", label="naive")
    plt.fill_between(
        range(len(naive_mean)),
        naive_mean-naive_std,
        naive_mean+naive_std,
        alpha=0.2,
        color="mediumpurple"
    )

    plt.plot(correlated_mean, color="mediumseagreen", label="correlated")
    plt.fill_between(
        range(len(correlated_mean)),
        correlated_mean-correlated_std,
        correlated_mean+correlated_std,
        alpha=0.2,
        color="mediumseagreen"
    )

    plt.title(f"{metric} at {param_to_vary}={PARAM_VAL}")
    plt.legend()
    plt.show()

# %%
metrics = set(results["correlated"][PARAM_VAL][0][0].keys()) - set(["day"])

for metric in metrics:

    naive_results = []
    correlated_results = []

    # for SEED in range(5):
    for SEED in range(len(results["correlated"][PARAM_VAL])):

        naive_results.append(
            [x[metric]\
            for x in results["naive"][PARAM_VAL][SEED]]
        )
        correlated_results.append(
            [x[metric]\
            for x in results["correlated"][PARAM_VAL][SEED]]
        )

    naive_results_ = np.array([(xi+[None]*(100-len(xi)))[:100] for xi in naive_results], dtype=float)
    correlated_results_ = np.array([(xi+[None]*(100-len(xi)))[:100] for xi in correlated_results][:100], dtype=float)

    diff = naive_results_ - correlated_results_
    diff_mean = np.nanmean(diff, axis=0)
    diff_std = np.nanstd(diff, axis=0)

    plt.plot(diff_mean, color="mediumseagreen")
    plt.fill_between(
        range(len(diff_mean)),
        diff_mean-diff_std,
        diff_mean+diff_std,
        alpha=0.2,
    )
    plt.hlines(0, 0, 100, color="black", linestyle="dashed")
    plt.title(f"Difference in {metric} (NP-CP) at {param_to_vary}={PARAM_VAL}")
    plt.show()
