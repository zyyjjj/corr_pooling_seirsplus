# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import numpy as np
from adjustText import adjust_text

# %% [markdown]
# ## Note: these are results of experiments started 9/9 afternoon on the pooling method `correlated_weak`. In this notebook we juxtapose the results from `correlated`, `correlated_weak`, and `naive`.

# %%
import os

os.listdir('/home/yz685/corr_pooling_seirsplus/results/')
# Out:
# ['deprecated',
#  'US_pop_size=10000_init_prev=0.001_num_groups=10_pool_size=10_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.01_num_groups=10_pool_size=10_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.01_num_groups=10_pool_size=5_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.1_num_groups=10_pool_size=20_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.001_num_groups=10_pool_size=30_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.1_num_groups=10_pool_size=5_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.001_num_groups=10_pool_size=5_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.1_num_groups=10_pool_size=30_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.01_num_groups=10_pool_size=30_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.01_num_groups=10_pool_size=20_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.1_num_groups=10_pool_size=10_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.001_num_groups=10_pool_size=20_horizon=100_beta=0.5_sigma=0.2_lamda=0.5_gamma=0.25_LoD=174',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'results_pre_08302023',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.5',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=1.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.1_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=7.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=1_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=2_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=40_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=5.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.001_num_groups=5_pool_size=50_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=10.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=100.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=1_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=2_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=5_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=4_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=4_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=4_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=4_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=3_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=3_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=3_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=3_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=7_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=7_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=7_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=7_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=6_pool_size=30_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=6_pool_size=20_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=6_pool_size=5_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0',
#  'US_pop_size=10000_init_prev=0.01_num_groups=6_pool_size=10_horizon=100_beta=0.1_sigma=0.2_lamda=0.5_gamma=0.25_LoD=1240_edge_weight=10_alpha=2.0_peak_VL=6.0_distancing_scale=50.0']

# %%
import pickle

NUM_TRIALS = 20


param_config = {
    "country": ["US"],

    "pop_size_default": 10000,

    "init_prev": [0.001, 0.01],
    "init_prev_default": 0.01,

    'horizon_default': 100,

    "num_groups_default": 5,
    "num_groups": [1,2,3,4,5,6,7],

    'pool_size': [5,10,20,30],
    'pool_size_default': 10,

    'LoD_default': 1240,
    'LoD': [1240],

    "edge_weight_default": 10,
    "edge_weight": [10],

    "alpha_default": 5.0,
    "alpha": [2.0],

    "peak_VL": [6.0],

    "distancing_scale": [50.0],

    "beta_default": 0.1, # transmissibility
    "sigma_default": 0.2, # rate E --> I_pre
    "lamda_default": 0.5, # rate I_pre --> I_(a)sym
    "gamma_default": 0.25 # rate I_sym --> R
}

# %%
import itertools

param_values = {}

for param in [
        "country", "pop_size", "init_prev", "num_groups", "pool_size", "horizon", 
        "beta", "sigma", "lamda", "gamma", "LoD", "edge_weight", "alpha", "peak_VL",
        "distancing_scale"
    ]:
        if param in param_config:
            param_values[param] = param_config[param]
        else:
            param_values[param] = [param_config[param+"_default"]]

all_param_configs = [dict(zip(param_values.keys(), x)) for x in itertools.product(*param_values.values())]

# %%
import copy
from collections import defaultdict
def defaultdict_list():
    return defaultdict(list)

# paths = []

df_data = []

all_data = []
trajectories = [] # list of tuples (dict of param_config_single, dict of {metric: [mean, std]})

for param_config_single in all_param_configs:

    traj_info = [param_config_single, {}]
    
    path = f"/home/yz685/corr_pooling_seirsplus/results/{param_config_single['country']}"
    for param in [
        "pop_size", "init_prev", "num_groups", "pool_size", "horizon", 
        "beta", "sigma", "lamda", "gamma", "LoD", "edge_weight", "alpha", "peak_VL", "distancing_scale"
    ]:
        path += f"_{param}={param_config_single[param]}"

    data = copy.deepcopy(param_config_single)

    # paths.append(path)

    results = defaultdict(list)

    for pooling_strategy in ["naive", "correlated", "correlated_weak"]:
        for i in range(1, NUM_TRIALS+1):
            filepath = path + f"/{pooling_strategy}/results_{i}.pickle"
            try:
                with open(filepath, "rb") as f:
                    results[pooling_strategy].append(pickle.load(f))
            except Exception as e:
                # print("error: ", e)
                continue

    if len(results["naive"]) == 0:
        continue

    metrics = set(results["correlated"][0][0].keys()) - set(["day", "VL_in_positive_pools"])

    for metric in metrics:
    # for metric in ["cumInfections", "cum_num_tests", "daily_sensitivity", "numActiveInfections", "mean_num_positives_in_positive_pool"]:
        
        for pooling_strategy in ["naive", "correlated", "correlated_weak"]:

            # print(pooling_strategy, metric)

            results_tmp = []
            for SEED in range(NUM_TRIALS):
                try:
                    results_tmp.append(
                        [x[metric]\
                        for x in results[pooling_strategy][SEED]]
                    )
                except:
                    pass

            results_tmp_ = np.array([(xi+[None]*(100-len(xi)))[:100] for xi in results_tmp], dtype=float)
            mean = np.nanmean(results_tmp_, axis=0)
            sem = np.nanstd(results_tmp_, axis=0)/np.sqrt(NUM_TRIALS)
            traj_info[1][metric+"_"+pooling_strategy] = [mean, sem] # TODO: confirm

            if metric in ["cumInfections", "cum_num_tests"]:
                data[f"{metric}_{pooling_strategy}_mean"] = mean[-1]
                data[f"{metric}_{pooling_strategy}_sem"] = sem[-1]
            else:
                data[f"{metric}_{pooling_strategy}_mean"] = np.nanmean(mean)
                data[f"{metric}_{pooling_strategy}_sem"] = np.nanmean(sem)

    all_data.append(data)
    trajectories.append(traj_info)

# %%
for i, j in enumerate(traj_info[1].keys()):
    print(i,j)
# Out:
# 0 cumInfections_naive
# 1 cumInfections_correlated
# 2 cumInfections_correlated_weak
# 3 daily_effective_efficiency_naive
# 4 daily_effective_efficiency_correlated
# 5 daily_effective_efficiency_correlated_weak
# 6 cum_positives_screened_naive
# 7 cum_positives_screened_correlated
# 8 cum_positives_screened_correlated_weak
# 9 cumRecovered_naive
# 10 cumRecovered_correlated
# 11 cumRecovered_correlated_weak
# 12 cum_positives_identified_naive
# 13 cum_positives_identified_correlated
# 14 cum_positives_identified_correlated_weak
# 15 cum_sensitivity_naive
# 16 cum_sensitivity_correlated
# 17 cum_sensitivity_correlated_weak
# 18 daily_effective_followup_efficiency_naive
# 19 daily_effective_followup_efficiency_correlated
# 20 daily_effective_followup_efficiency_correlated_weak
# 21 median_num_positives_in_positive_pool_naive
# 22 median_num_positives_in_positive_pool_correlated
# 23 median_num_positives_in_positive_pool_correlated_weak
# 24 mean_num_positives_in_positive_pool_naive
# 25 mean_num_positives_in_positive_pool_correlated
# 26 mean_num_positives_in_positive_pool_correlated_weak
# 27 num_susceptible_neighbors_of_unidentified_positives_naive
# 28 num_susceptible_neighbors_of_unidentified_positives_correlated
# 29 num_susceptible_neighbors_of_unidentified_positives_correlated_weak
# 30 cum_num_tests_naive
# 31 cum_num_tests_correlated
# 32 cum_num_tests_correlated_weak
# 33 numQuarantinedInfections_naive
# 34 numQuarantinedInfections_correlated
# 35 numQuarantinedInfections_correlated_weak
# 36 mean_num_identifiable_positives_in_positive_pool_naive
# 37 mean_num_identifiable_positives_in_positive_pool_correlated
# 38 mean_num_identifiable_positives_in_positive_pool_correlated_weak
# 39 median_num_identifiable_positives_in_positive_pool_naive
# 40 median_num_identifiable_positives_in_positive_pool_correlated
# 41 median_num_identifiable_positives_in_positive_pool_correlated_weak
# 42 numActiveInfections_naive
# 43 numActiveInfections_correlated
# 44 numActiveInfections_correlated_weak
# 45 daily_sensitivity_naive
# 46 daily_sensitivity_correlated
# 47 daily_sensitivity_correlated_weak
# 48 num_susceptible_neighbors_of_identified_positives_naive
# 49 num_susceptible_neighbors_of_identified_positives_correlated
# 50 num_susceptible_neighbors_of_identified_positives_correlated_weak

# %%
metric_to_english = {
    "cumInfections": "Cumulative Infections",
    "cum_num_tests": "Cumulative Test Consumption",
    "daily_sensitivity": r"Daily Sensitivity ($1-\beta$)",
    "numActiveInfections": "Active Infections",
    "mean_num_positives_in_positive_pool": "Mean # Positives in Positive Pools",
    "mean_num_identifiable_positives_in_positive_pool": "Mean # Identifiable Positives in Positive Pools",
    "daily_effective_efficiency": r"Daily Effective Efficiency ($\gamma$)",
    "daily_effective_followup_efficiency": r"Daily Effective Followup Efficiency ($\eta$)",
    "num_susceptible_neighbors_of_identified_positives": "# Susceptible Neighbors of Identified Positives",
}

colors = {
    "naive": "mediumpurple",
    "correlated": "mediumseagreen",
    "correlated_weak": "dodgerblue",
}

legends_dict = {
    "naive": "naive pooling",
    "correlated": "household correlated pooling",
    "correlated_weak": "community correlated pooling",
}

def plot_trajectory(traj_info, metrics_to_plot = None, pooling_methods = ["naive", "correlated", "correlated_weak"], save_fig=False):

    if metrics_to_plot == None:
        metrics_to_plot = traj_info[1].keys()

    # print(f"init_prev={traj_info[0]['init_prev']}, peak_VL={traj_info[0]['peak_VL']}, num_groups={traj_info[0]['num_groups']}, alpha={traj_info[0]['alpha']}, pool_size={traj_info[0]['pool_size']}, LoD={traj_info[0]['LoD']}, edge_weight={traj_info[0]['edge_weight']}, distancing_scale={traj_info[0]['distancing_scale']}")
    print(f"num_groups={traj_info[0]['num_groups']}, pool_size={traj_info[0]['pool_size']}")

    fig, axs = plt.subplots(2, (len(metrics_to_plot)+1)//2, figsize=(5*len(metrics_to_plot)/2, 3*2))
    fig.tight_layout()
    
    for i, metric in enumerate(metrics_to_plot):

        row_idx = i // ((len(metrics_to_plot)+1)//2)
        col_idx = i % ((len(metrics_to_plot)+1)//2)

        for pooling_method in pooling_methods:
            mean = traj_info[1][metric+"_"+pooling_method][0]
            sem = traj_info[1][metric+"_"+pooling_method][1]
            axs[row_idx][col_idx].plot(mean, label=legends_dict[pooling_method], color=colors[pooling_method])
            axs[row_idx][col_idx].fill_between(
                range(len(mean)),
                mean-2*sem,
                mean+2*sem,
                alpha=0.2,
                color=colors[pooling_method]
            )

        axs[row_idx][col_idx].set_title(metric_to_english[metric])
        if row_idx == 1 and col_idx == 2:
            axs[row_idx][col_idx].legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    fig.delaxes(axs[1,3])

    if save_fig:
        plt.savefig("../../figures/dynamic_sim.pdf", bbox_inches='tight')

# %%
for j in range(len(trajectories)):
    if trajectories[j][0]["distancing_scale"] == 50 and trajectories[j][0]["num_groups"] == 5 and trajectories[j][0]["pool_size"] == 20:
        plot_trajectory(
            trajectories[j], 
            metrics_to_plot = [
                "cumInfections", 
                "cum_num_tests", 
                "numActiveInfections",
                "mean_num_identifiable_positives_in_positive_pool",
                "daily_sensitivity",
                "daily_effective_efficiency", 
                "daily_effective_followup_efficiency",
                # "mean_num_positives_in_positive_pool",
                # "num_susceptible_neighbors_of_unidentified_positives"
                
                # "cum_positives_identified"
                # "num_susceptible_neighbors_of_identified_positives"
            ],
            save_fig=True
        )
# Out:
# num_groups=5, pool_size=20

# %%
import pandas as pd
df = pd.DataFrame(all_data)
# df.dropna(inplace=True)

# %%
df
# Out:
#    country  pop_size  init_prev  num_groups  pool_size  horizon  beta  sigma
# 0       US     10000       0.01           1          5      100   0.1    0.2  \
# 1       US     10000       0.01           1         10      100   0.1    0.2
# 2       US     10000       0.01           1         20      100   0.1    0.2
# 3       US     10000       0.01           1         30      100   0.1    0.2
# 4       US     10000       0.01           2          5      100   0.1    0.2
# 5       US     10000       0.01           2         10      100   0.1    0.2
# 6       US     10000       0.01           2         20      100   0.1    0.2
# 7       US     10000       0.01           2         30      100   0.1    0.2
# 8       US     10000       0.01           3          5      100   0.1    0.2
# 9       US     10000       0.01           3         10      100   0.1    0.2
# 10      US     10000       0.01           3         20      100   0.1    0.2
# 11      US     10000       0.01           3         30      100   0.1    0.2
# 12      US     10000       0.01           4          5      100   0.1    0.2
# 13      US     10000       0.01           4         10      100   0.1    0.2
# 14      US     10000       0.01           4         20      100   0.1    0.2
# 15      US     10000       0.01           4         30      100   0.1    0.2
# 16      US     10000       0.01           5          5      100   0.1    0.2
# 17      US     10000       0.01           5         10      100   0.1    0.2
# 18      US     10000       0.01           5         20      100   0.1    0.2
# 19      US     10000       0.01           5         30      100   0.1    0.2
# 20      US     10000       0.01           6          5      100   0.1    0.2
# 21      US     10000       0.01           6         10      100   0.1    0.2
# 22      US     10000       0.01           6         20      100   0.1    0.2
# 23      US     10000       0.01           6         30      100   0.1    0.2
# 24      US     10000       0.01           7          5      100   0.1    0.2
# 25      US     10000       0.01           7         10      100   0.1    0.2
# 26      US     10000       0.01           7         20      100   0.1    0.2
# 27      US     10000       0.01           7         30      100   0.1    0.2
#
#     lamda  gamma  ...  daily_sensitivity_correlated_mean
# 0     0.5   0.25  ...                           0.146475  \
# 1     0.5   0.25  ...                           0.143601
# 2     0.5   0.25  ...                           0.139274
# 3     0.5   0.25  ...                           0.138712
# 4     0.5   0.25  ...                           0.262192
# 5     0.5   0.25  ...                           0.257177
# 6     0.5   0.25  ...                           0.252914
# 7     0.5   0.25  ...                           0.248413
# 8     0.5   0.25  ...                           0.334381
# 9     0.5   0.25  ...                           0.332078
# 10    0.5   0.25  ...                           0.322670
# 11    0.5   0.25  ...                           0.309030
# 12    0.5   0.25  ...                           0.430857
# 13    0.5   0.25  ...                           0.426181
# 14    0.5   0.25  ...                           0.400485
# 15    0.5   0.25  ...                           0.383242
# 16    0.5   0.25  ...                           0.438410
# 17    0.5   0.25  ...                           0.427588
# 18    0.5   0.25  ...                           0.398110
# 19    0.5   0.25  ...                           0.381193
# 20    0.5   0.25  ...                           0.587847
# 21    0.5   0.25  ...                           0.541164
# 22    0.5   0.25  ...                           0.491572
# 23    0.5   0.25  ...                           0.465171
# 24    0.5   0.25  ...                           0.527038
# 25    0.5   0.25  ...                           0.478949
# 26    0.5   0.25  ...                           0.440624
# 27    0.5   0.25  ...                           0.423327
#
#     daily_sensitivity_correlated_sem  daily_sensitivity_correlated_weak_mean
# 0                           0.008977                                0.145754  \
# 1                           0.008793                                0.139871
# 2                           0.009121                                0.136901
# 3                           0.009425                                0.136528
# 4                           0.016187                                0.258685
# 5                           0.016480                                0.254086
# 6                           0.016792                                0.250032
# 7                           0.016297                                0.244852
# 8                           0.017507                                0.332847
# 9                           0.018301                                0.329859
# 10                          0.017333                                0.316293
# 11                          0.017056                                0.298878
# 12                          0.020933                                0.430723
# 13                          0.020865                                0.421427
# 14                          0.019218                                0.380879
# 15                          0.020213                                0.354634
# 16                          0.022753                                0.438914
# 17                          0.020641                                0.409658
# 18                          0.020378                                0.371041
# 19                          0.019895                                0.346351
# 20                          0.022478                                0.575533
# 21                          0.021864                                0.500389
# 22                          0.022557                                0.443800
# 23                          0.023420                                0.412192
# 24                          0.027597                                0.501175
# 25                          0.026121                                0.443321
# 26                          0.024929                                0.396419
# 27                          0.024711                                0.375250
#
#     daily_sensitivity_correlated_weak_sem
# 0                                0.008620  \
# 1                                0.008090
# 2                                0.008336
# 3                                0.008442
# 4                                0.015129
# 5                                0.016335
# 6                                0.015723
# 7                                0.015178
# 8                                0.017129
# 9                                0.017135
# 10                               0.016449
# 11                               0.015448
# 12                               0.020715
# 13                               0.020179
# 14                               0.018296
# 15                               0.017143
# 16                               0.020060
# 17                               0.019043
# 18                               0.017751
# 19                               0.017862
# 20                               0.020678
# 21                               0.020537
# 22                               0.020115
# 23                               0.019865
# 24                               0.026260
# 25                               0.023012
# 26                               0.022666
# 27                               0.022315
#
#     num_susceptible_neighbors_of_identified_positives_naive_mean
# 0                                          161.691526             \
# 1                                          169.346000
# 2                                          177.643500
# 3                                          178.062000
# 4                                          162.603500
# 5                                          173.879500
# 6                                          180.906500
# 7                                          194.554000
# 8                                          181.588000
# 9                                          188.774000
# 10                                         206.188000
# 11                                         217.204500
# 12                                         196.448500
# 13                                         205.482000
# 14                                         227.825500
# 15                                         229.219500
# 16                                         212.818500
# 17                                         228.212500
# 18                                         232.411000
# 19                                         230.270000
# 20                                         232.684500
# 21                                         231.972000
# 22                                         228.695500
# 23                                         224.998500
# 24                                         234.348500
# 25                                         223.720000
# 26                                         218.054000
# 27                                         218.806500
#
#     num_susceptible_neighbors_of_identified_positives_naive_sem
# 0                                           13.482078            \
# 1                                           13.329545
# 2                                           13.639455
# 3                                           13.882219
# 4                                           14.128261
# 5                                           14.257847
# 6                                           14.874788
# 7                                           15.202950
# 8                                           15.894697
# 9                                           15.364913
# 10                                          17.336313
# 11                                          17.306715
# 12                                          15.591094
# 13                                          16.380283
# 14                                          16.905633
# 15                                          17.250063
# 16                                          17.029595
# 17                                          17.934224
# 18                                          16.786057
# 19                                          17.411479
# 20                                          16.936831
# 21                                          16.449650
# 22                                          15.678552
# 23                                          17.685465
# 24                                          16.435708
# 25                                          15.818564
# 26                                          15.133539
# 27                                          16.044613
#
#     num_susceptible_neighbors_of_identified_positives_correlated_mean
# 0                                            162.9420                  \
# 1                                            169.3405
# 2                                            171.0490
# 3                                            171.7430
# 4                                            167.9200
# 5                                            168.2775
# 6                                            174.7225
# 7                                            178.0010
# 8                                            184.1610
# 9                                            182.3525
# 10                                           189.2115
# 11                                           205.4395
# 12                                           184.7955
# 13                                           192.0130
# 14                                           214.1320
# 15                                           212.8420
# 16                                           196.5255
# 17                                           210.2735
# 18                                           223.0505
# 19                                           231.0790
# 20                                           218.8865
# 21                                           231.3730
# 22                                           232.7275
# 23                                           236.5375
# 24                                           235.4420
# 25                                           239.6690
# 26                                           237.0950
# 27                                           234.4760
#
#     num_susceptible_neighbors_of_identified_positives_correlated_sem
# 0                                           14.469334                 \
# 1                                           14.163371
# 2                                           14.988399
# 3                                           16.553600
# 4                                           15.178682
# 5                                           15.339993
# 6                                           16.385068
# 7                                           17.145760
# 8                                           16.466470
# 9                                           17.156316
# 10                                          16.502122
# 11                                          17.011011
# 12                                          17.133640
# 13                                          16.961208
# 14                                          18.275021
# 15                                          18.501915
# 16                                          18.077237
# 17                                          17.957613
# 18                                          19.148925
# 19                                          18.531862
# 20                                          18.837182
# 21                                          17.706005
# 22                                          18.337193
# 23                                          19.010289
# 24                                          18.204291
# 25                                          17.238614
# 26                                          18.111665
# 27                                          17.322268
#
#     num_susceptible_neighbors_of_identified_positives_correlated_weak_mean
# 0                                            154.5535                       \
# 1                                            176.1805
# 2                                            170.2460
# 3                                            177.9425
# 4                                            172.8060
# 5                                            160.7620
# 6                                            172.0050
# 7                                            182.3560
# 8                                            179.8045
# 9                                            185.3015
# 10                                           197.9170
# 11                                           209.7400
# 12                                           187.0940
# 13                                           199.4925
# 14                                           211.7800
# 15                                           224.0910
# 16                                           207.4500
# 17                                           219.3885
# 18                                           233.2950
# 19                                           234.1850
# 20                                           231.6355
# 21                                           234.0975
# 22                                           234.5605
# 23                                           232.1450
# 24                                           238.3760
# 25                                           236.6060
# 26                                           231.3620
# 27                                           227.9640
#
#     num_susceptible_neighbors_of_identified_positives_correlated_weak_sem
# 0                                           13.044510
# 1                                           14.245084
# 2                                           14.825739
# 3                                           15.997286
# 4                                           15.324407
# 5                                           15.482754
# 6                                           15.323609
# 7                                           16.132008
# 8                                           16.961483
# 9                                           16.732273
# 10                                          17.866909
# 11                                          17.179759
# 12                                          16.335569
# 13                                          16.687742
# 14                                          17.219671
# 15                                          17.740043
# 16                                          18.055120
# 17                                          17.800357
# 18                                          18.361539
# 19                                          18.816669
# 20                                          17.683604
# 21                                          17.540901
# 22                                          17.734706
# 23                                          18.162760
# 24                                          17.861411
# 25                                          16.991340
# 26                                          16.430775
# 27                                          16.645990
#
# [28 rows x 117 columns]

# %%
for pm1, pm2 in zip(["naive", "naive"], ["correlated", "correlated_weak"]):

    df[f"cumInfections_diff_rel_{pm1}_{pm2}"] = (df[f"cumInfections_{pm1}_mean"] - df[f"cumInfections_{pm2}_mean"])/df[f"cumInfections_{pm1}_mean"]
    df[f"cum_num_tests_diff_rel_{pm1}_{pm2}"] = (df[f"cum_num_tests_{pm1}_mean"] - df[f"cum_num_tests_{pm2}_mean"]) / df[f"cum_num_tests_{pm1}_mean"]

# %%
df.columns
# Out:
# Index(['country', 'pop_size', 'init_prev', 'num_groups', 'pool_size',
#        'horizon', 'beta', 'sigma', 'lamda', 'gamma',
#        ...
#        'num_susceptible_neighbors_of_identified_positives_naive_mean',
#        'num_susceptible_neighbors_of_identified_positives_naive_sem',
#        'num_susceptible_neighbors_of_identified_positives_correlated_mean',
#        'num_susceptible_neighbors_of_identified_positives_correlated_sem',
#        'num_susceptible_neighbors_of_identified_positives_correlated_weak_mean',
#        'num_susceptible_neighbors_of_identified_positives_correlated_weak_sem',
#        'cumInfections_diff_rel_naive_correlated',
#        'cum_num_tests_diff_rel_naive_correlated',
#        'cumInfections_diff_rel_naive_correlated_weak',
#        'cum_num_tests_diff_rel_naive_correlated_weak'],
#       dtype='object', length=121)

# %%
import matplotlib.ticker as mtick

df_sub = df[
    (df["init_prev"] == 0.01)
    # & (df["num_groups"] != 1)
    & (df["alpha"] == 2.0)
    & (df["distancing_scale"] == 50)
]

init_prev_values = np.unique(df["init_prev"])
colordict = {
    0.001: "green",
    0.01: "blue",
    0.1: "red"
}
markerdict = {
    6.0: "*",
    7.0: "^",
    6.5: "o"
}

fillstyledict = {
    2.0: "none",
    5.0: "full",
}


for pm1, pm2 in zip(["naive", "naive"], ["correlated", "correlated_weak"]):

    plt.figure(figsize=(10,5))
    for _, row in df_sub.iterrows():
        plt.scatter(
            row[f"cumInfections_diff_rel_{pm1}_{pm2}"], 
            row[f"cum_num_tests_diff_rel_{pm1}_{pm2}"], 
            color="tab:blue",
        )


    # plt.hlines(0,-0.3, 0.4, color="gray", linestyle="--")
    # plt.vlines(0,-0.1,0.3, color="gray", linestyle="--")
    plt.xlabel(f"Relative difference in cumulative infections ({pm1}-{pm2})")
    plt.ylabel(f"Relative difference in cumulative tests ({pm1}-{pm2})")

    plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    plt.gca().xaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    # plt.xscale('log')

    plt.title(f"Relative difference ({pm1}-{pm2}) in cumulative infections and tests across different policies")
    # plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    # plt.savefig("../../figures/relative_diff.pdf", bbox_inches='tight')

# %%
pooling_methods = ["naive", "correlated", "correlated_weak"]

df_sub = df[
    (df["init_prev"] == 0.01)
    & (df["distancing_scale"] == 50)
    & (df["alpha"] == 2.0)
]

init_prev_values = np.unique(df["init_prev"])

markerdict = { # screening frequency
    1: "*",
    2: "^",
    3: "s",
    4: "P",
    5: "o",
    6: "X",
    7: "D"   
}

plt.figure(figsize=(10,5))
legends = {}

all_results = defaultdict(list)
pareto_results = defaultdict(list)

for pooling_method in pooling_methods:

    for row_idx, row in df_sub.iterrows():
        result_single = [row[f"cum_num_tests_{pooling_method}_mean"], row[f"cumInfections_{pooling_method}_mean"], row["num_groups"], row["pool_size"]]
        all_results[pooling_method].append(result_single)
    
    # sort pareto_np and pareto_cp by num_tests in ascending order
    # in each np/cp list, the point with the smallest num_tests cannot be dominated by any other point
    all_results[pooling_method].sort(key=lambda x: x[0])

    # then, iterate through the sorted list and keep only points not dominated by the previous point
    # it suffices to compare the kth with the k-1 th point only, because k-1 th point is not dominated by any point before it (ie must have lower cum infections)
    # so if the kth point has lower cum infections than the k-1 th point, then it has lower cum infections than (is not dominated by) any point before it
    pareto_results[pooling_method] = [all_results[pooling_method][0]]
    for i in range(1, len(all_results[pooling_method])):
        if all_results[pooling_method][i][1] < pareto_results[pooling_method][-1][1]:
            pareto_results[pooling_method].append(all_results[pooling_method][i])
    
    for i in range(len(pareto_results[pooling_method])):
        num_tests, cum_infections, num_groups, pool_size = pareto_results[pooling_method][i]
        scatter = plt.scatter(
            num_tests,
            cum_infections,
            marker=markerdict[num_groups],
            color=colors[pooling_method],
        )
        if pooling_method == "naive":
            legends[f"screen every {num_groups} days"] = scatter
        if num_groups == 1:
            legends[pooling_method] = scatter
        plt.annotate(f"{pool_size}", (num_tests+100, cum_infections+30), color=colors[pooling_method])

plt.xlabel("Test consumption")
plt.ylabel("Cumulative infections")

plt.xscale('log')
plt.yscale('log')

plt.legend(legends.values(), legends.keys(), loc='upper right')

plt.title("Cumulative infections vs. test consumption across different policies")
# plt.savefig("../../figures/diff.pdf", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Cumulative infections vs. test consumption across different policies')

# %%
pooling_methods = ["naive", "correlated_weak", "correlated"]

df_sub = df[
    (df["init_prev"] == 0.01)
    & (df["distancing_scale"] == 50)
    & (df["alpha"] == 2.0)
]

init_prev_values = np.unique(df["init_prev"])

markerdict = { # screening frequency
    "naive": "^",
    "correlated": "o",
    "correlated_weak": "D"   
}

legends_dict = {
    "naive": "naive pooling",
    "correlated": "household correlated pooling",
    "correlated_weak": "community correlated pooling",
}

colors = {
    "naive": "mediumpurple",
    "correlated": "mediumseagreen",
    "correlated_weak": "dodgerblue",
}

plt.figure(figsize=(10,5))
legends = {}

all_results = defaultdict(list)
pareto_results = defaultdict(list)

texts = []

for pooling_method in pooling_methods:

    for row_idx, row in df_sub.iterrows():
        result_single = [row[f"cum_num_tests_{pooling_method}_mean"], row[f"cumInfections_{pooling_method}_mean"], row["num_groups"], row["pool_size"]]
        all_results[pooling_method].append(result_single)
    
    # sort pareto_np and pareto_cp by num_tests in ascending order
    # in each np/cp list, the point with the smallest num_tests cannot be dominated by any other point
    all_results[pooling_method].sort(key=lambda x: x[0])

    # then, iterate through the sorted list and keep only points not dominated by the previous point
    # it suffices to compare the kth with the k-1 th point only, because k-1 th point is not dominated by any point before it (ie must have lower cum infections)
    # so if the kth point has lower cum infections than the k-1 th point, then it has lower cum infections than (is not dominated by) any point before it
    pareto_results[pooling_method] = [all_results[pooling_method][0]]
    for i in range(1, len(all_results[pooling_method])):
        if all_results[pooling_method][i][1] < pareto_results[pooling_method][-1][1]:
            pareto_results[pooling_method].append(all_results[pooling_method][i])
    
    for i in range(len(pareto_results[pooling_method])):
        num_tests, cum_infections, num_groups, pool_size = pareto_results[pooling_method][i]
        scatter = plt.scatter(
            num_tests,
            cum_infections,
            color=colors[pooling_method],
            marker=markerdict[pooling_method],
        )
        if num_groups == 1:
            legends[legends_dict[pooling_method]] = scatter
        if pooling_method == "correlated":
            if num_groups == 4 and pool_size == 10:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*(0.87), cum_infections*(0.98)), color=colors[pooling_method])
            elif num_groups == 2 and pool_size == 10:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*(0.87), cum_infections*(0.98)), color=colors[pooling_method])
            elif num_groups == 1 and pool_size == 10:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*1.02, cum_infections*(0.96)), color=colors[pooling_method])
            elif num_groups == 1 and pool_size == 5:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*0.89, cum_infections*(0.97)), color=colors[pooling_method])
            else:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*(0.89), cum_infections*(0.95)), color=colors[pooling_method])
        elif pooling_method == "correlated_weak":
            if num_groups == 3 and pool_size == 10:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*0.95, cum_infections*1.02), color=colors[pooling_method])
            elif num_groups == 1 and pool_size == 5:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*1.02, cum_infections*0.98), color=colors[pooling_method])
            elif num_groups == 2 and pool_size == 10:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*1.02, cum_infections), color=colors[pooling_method])
            else:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests, cum_infections*1.02), color=colors[pooling_method])
        else:
            if num_groups == 6 and pool_size == 10:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests*1.02, cum_infections*0.98), color=colors[pooling_method])
            elif num_groups == 2 and pool_size == 5:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests, cum_infections*1.05), color=colors[pooling_method])
            else:
                plt.annotate(f"({num_groups},{pool_size})", (num_tests, cum_infections*1.02), color=colors[pooling_method])
        

plt.xlabel("Test consumption")
plt.ylabel("Cumulative infections")

plt.xlim(2.5*1e4, 2.5*1e5)
plt.ylim(1.7*1e3, 5.8*1e3)

plt.xscale('log')
plt.yscale('log')

plt.legend(legends.values(), legends.keys(), loc='upper right')

plt.title("Cumulative infections vs. test consumption across different screening policies")
plt.savefig("../../figures/diff_pareto.pdf", bbox_inches='tight')

# %%
pooling_methods = ["naive", "correlated", "correlated_weak"]

df_sub = df[
    (df["init_prev"] == 0.01)
    & (df["distancing_scale"] == 50)
    & (df["alpha"] == 2.0)
]

init_prev_values = np.unique(df["init_prev"])

markerdict = { # screening frequency
    1: "*",
    2: "^",
    3: "s",
    4: "P",
    5: "o",
    6: "X",
    7: "D"   
}

plt.figure(figsize=(10,5))
legends = {}

all_results = defaultdict(list)
pareto_results = defaultdict(list)

texts = []

for pooling_method in pooling_methods:

    for row_idx, row in df_sub.iterrows():
        result_single = [row[f"cum_num_tests_{pooling_method}_mean"], row[f"cumInfections_{pooling_method}_mean"], row["num_groups"], row["pool_size"]]
        all_results[pooling_method].append(result_single)
    
    # sort pareto_np and pareto_cp by num_tests in ascending order
    # in each np/cp list, the point with the smallest num_tests cannot be dominated by any other point
    all_results[pooling_method].sort(key=lambda x: x[0])

    # then, iterate through the sorted list and keep only points not dominated by the previous point
    # it suffices to compare the kth with the k-1 th point only, because k-1 th point is not dominated by any point before it (ie must have lower cum infections)
    # so if the kth point has lower cum infections than the k-1 th point, then it has lower cum infections than (is not dominated by) any point before it
    pareto_results[pooling_method] = [all_results[pooling_method][0]]
    for i in range(1, len(all_results[pooling_method])):
        if all_results[pooling_method][i][1] < pareto_results[pooling_method][-1][1]:
            pareto_results[pooling_method].append(all_results[pooling_method][i])
    
    for i in range(len(pareto_results[pooling_method])):
        num_tests, cum_infections, num_groups, pool_size = pareto_results[pooling_method][i]
        scatter = plt.scatter(
            num_tests,
            cum_infections,
            color=colors[pooling_method],
        )
        if num_groups == 1:
            legends[pooling_method] = scatter
        if pooling_method == "correlated":
            # texts.append(plt.text(num_tests-3000, cum_infections-100, f"({num_groups},{pool_size})", color=colors[pooling_method]))
            texts.append(plt.text(num_tests*(0.89), cum_infections*(0.95), f"({num_groups},{pool_size})", color=colors[pooling_method]))
            
        else:
            # texts.append(plt.text(num_tests+100, cum_infections+30, f"({num_groups},{pool_size})", color=colors[pooling_method]))
            texts.append(plt.text(num_tests, cum_infections*1.02, f"({num_groups},{pool_size})", color=colors[pooling_method]))

        # plt.annotate(f"({num_groups},{pool_size})", (num_tests+100, cum_infections+30), color=colors[pooling_method])

adjust_text(
    texts, 
    # only_move={'points':'y', 'texts':'xy'}
    only_move={'text':'xy'},
    force_text = (0.001,0.05),
    force_static = (0.01, 0.01)
    # force_pull=(0.1, 0.1),
    # arrowprops=dict(arrowstyle='->', color='blue')
)

plt.xlabel("Test consumption")
plt.ylabel("Cumulative infections")

plt.xscale('log')
plt.yscale('log')

plt.legend(legends.values(), legends.keys(), loc='upper right')

plt.title("Cumulative infections vs. test consumption across different policies")
# plt.savefig("../../figures/diff.pdf", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Cumulative infections vs. test consumption across different policies')

# %%
pooling_methods = ["naive", "correlated"]

df_sub = df[
    (df["init_prev"] == 0.01)
    & (df["distancing_scale"] == 50)
    & (df["alpha"] == 2.0)
]

init_prev_values = np.unique(df["init_prev"])

markerdict = { # screening frequency
    1: "*",
    2: "^",
    3: "s",
    4: "P",
    5: "o",
    6: "X",
    7: "D"
}

plt.figure(figsize=(10,5))
legends = {}

all_results = defaultdict(list)
pareto_results = defaultdict(list)

for pooling_method in pooling_methods:

    for row_idx, row in df_sub.iterrows():
        result_single = [row[f"cum_num_tests_{pooling_method}_mean"], row[f"cumInfections_{pooling_method}_mean"], row["num_groups"], row["pool_size"]]
        all_results[pooling_method].append(result_single)
    
    # sort pareto_np and pareto_cp by num_tests in ascending order
    # in each np/cp list, the point with the smallest num_tests cannot be dominated by any other point
    all_results[pooling_method].sort(key=lambda x: x[0])

    # then, iterate through the sorted list and keep only points not dominated by the previous point
    # it suffices to compare the kth with the k-1 th point only, because k-1 th point is not dominated by any point before it (ie must have lower cum infections)
    # so if the kth point has lower cum infections than the k-1 th point, then it has lower cum infections than (is not dominated by) any point before it
    pareto_results[pooling_method] = [all_results[pooling_method][0]]
    for i in range(1, len(all_results[pooling_method])):
        if all_results[pooling_method][i][1] < pareto_results[pooling_method][-1][1]:
            pareto_results[pooling_method].append(all_results[pooling_method][i])
    
    for i in range(len(pareto_results[pooling_method])):
        num_tests, cum_infections, num_groups, pool_size = pareto_results[pooling_method][i]
        scatter = plt.scatter(
            num_tests,
            cum_infections,
            marker=markerdict[num_groups],
            color=colors[pooling_method],
        )
        legends[f"{pooling_method}, screen every {num_groups} days"] = scatter
        plt.annotate(f"{pool_size}", (num_tests+100, cum_infections+30), color=colors[pooling_method])

plt.xlabel("Test consumption")
plt.ylabel("Cumulative infections")

plt.xscale('log')
plt.yscale('log')

plt.legend(legends.values(), legends.keys(), loc='upper right')

plt.title("Cumulative infections vs. test consumption across different policies")
# plt.savefig("../../figures/diff.pdf", bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Cumulative infections vs. test consumption across different policies')
